# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset_toronto_raptors.csv')

# %%
df.head()
# Out:
#     game_id                 game_date        home_team  \
# 0  11300022  2013-10-09T00:00:00.000Z  Toronto_Raptors
# 1  11300022  2013-10-09T00:00:00.000Z  Toronto_Raptors
# 2  11300022  2013-10-09T00:00:00.000Z  Toronto_Raptors
# 3  11300022  2013-10-09T00:00:00.000Z  Toronto_Raptors
# 4  11300022  2013-10-09T00:00:00.000Z  Toronto_Raptors
#
#                 away_team  event_num  event_type  period  minute_game  \
# 0  Minnesota_Timberwolves         62           1       1         5.53
# 1  Minnesota_Timberwolves        202           4       2        18.37
# 2  Minnesota_Timberwolves        258           1       2        24.00
# 3  Minnesota_Timberwolves        331           8       3        30.03
# 4  Minnesota_Timberwolves        410           2       3        35.98
#
#   wc_time_string time_quarter  ...  player3_team_id  \
# 0        7:19 PM         6:28  ...              NaN
# 1        7:50 PM         5:38  ...              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524860 entries, 0 to 524859
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   game_id                    524860 non-null  int64
#  1   game_date                  524860 non-null  object
#  2   home_team                  524860 non-null  object
#  3   away_team                  524860 non-null  object
#  4   event_num                  524860 non-null  int64
#  5   event_type                 524860 non-null  int64
#  6   period                     524860 non-null  int64
#  7   minute_game                524860 non-null  float64
#  8   wc_time_string             524860 non-null  object
#  9   time_quarter               524860 non-null  object
#  10  person1type                524630 non-null  float64
#  11  player1_id                 524860 non-null  int64
#  12  person2type                524860 non-null  int64
# ...

# %%
# One-hot encode categorical features
cat_encode = ['away_team', 'event_type']

pd.get_dummies(df, columns=cat_encode).columns
# Out:
# Index(['game_id', 'game_date', 'home_team', 'event_num', 'period',
#        'minute_game', 'wc_time_string', 'time_quarter', 'person1type',
#        'player1_id', 'person2type', 'player2_id', 'person3type', 'player3_id',
#        'video_available_flag', 'season', 'player1_name', 'player1_team_id',
#        'player1_team_abbreviation', 'player2_name', 'player2_team_id',
#        'player2_team_abbreviation', 'player3_name', 'player3_team_id',
#        'player3_team_abbreviation', 'score_margin_complete', 'score_complete',
#        'away_score_complete', 'home_score_complete', 'team_leading_complete',
#        'game_month', 'game_day', 'game_year', 'away_team_Atlanta_Hawks',
#        'away_team_Boston_Celtics', 'away_team_Brooklyn_Nets',
#        'away_team_Buenos Aires_San Lorenzo', 'away_team_Charlotte_Bobcats',
#        'away_team_Charlotte_Hornets', 'away_team_Chicago_Bulls',
#        'away_team_Cleveland_Cavaliers', 'away_team_Dallas_Mavericks',
# ...

# %%
# line plot
import matplotlib.pyplot as plt

# add line plot for score_margin_complete and score_margin
plt.figure(figsize=(12, 6))
plt.plot(df['score_margin_complete'], label='score_margin_complete')
